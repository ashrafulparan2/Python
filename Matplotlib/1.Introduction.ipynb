# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
x=np.arange(1,8)
x
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
y=np.random.randint(46, 52, size=7)
y
# Out:
# array([48, 46, 48, 51, 48, 46, 48])

# %%
plt.xlabel('Day')
plt.ylabel('Temp.')
plt.title('Weather')
plt.plot(x,y, color='green', linewidth=5, linestyle='dashed')
