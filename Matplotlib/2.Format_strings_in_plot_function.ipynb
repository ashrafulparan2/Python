# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
x=np.arange(1,8)
x
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
y=np.random.randint(46, 52, size=7)
y
# Out:
# array([48, 50, 47, 49, 48, 50, 49])

# %%
plt.plot(x,y, 'g+--')

# %%
plt.plot(x,y, '--r*')

# %%
plt.plot(x,y, 'D--')

# %%
plt.plot(x,y, color='#000', marker='D', linestyle="", markersize=10)

# %%
plt.plot(x,y, color='green', alpha=0.2)
